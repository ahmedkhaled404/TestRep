# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Ahmed Khaled</b><br>
#     I'm currently a student and I plan to be a Data Scientist

# %% [markdown]
# *I am intersted in Data Science because i think it's a futuristic field and would never be old  besides I love finding solutins.*

# %% [markdown]
# ### The following code gets the mean of 3 numbers

# %%
x=5
y=6
z=7
sum = x+y+z
mean = sum/3
print("mean=",mean)
# Out:
# mean= 6.0

# %% [markdown]
# <a>www.facebook.com</a><br>
# 1. one
# 2. two <br>
# | ID | Sex | Name |
# | ---- | ---- | ---- |
# | 1 | F | Anna |
# | 2 | M | Messi | <br>
#
# Horizontal Rule.
# ---
# Sure!
